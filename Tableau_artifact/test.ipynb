# %%
# count the number of lines in a file

# load a file
file = open('dataset/MisBot/User_Instances/inference_data.jsonl')

# count the number of lines
file = file.readlines()
print(len(file))
# Out:
# 942430

# %%
# count the number of lines in a file

# load a file
file = open('dataset/MisBot/Information_Instances/misinformation.jsonl')

# count the number of lines
file = file.readlines()
print(len(file))
# Out:
# 7560
